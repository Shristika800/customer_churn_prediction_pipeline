# %% [markdown]
# # churn eda
# need to clean this later

# %%
import pandas as pd
df = pd.read_csv('data/sample/customer_churn_sample.csv')
df.head()

# %%
import pandas as pd
df = pd.read_csv('data/raw/WA_Fn-UseC_-Telco-Customer-Churn.csv')
df.head()

# %%
df.shape

# %%
df.isnull().sum()

# %%
# TotalCharges has some blanks i think
df['TotalCharges'] = pd.to_numeric(df['TotalCharges'], errors='coerce')
df.isnull().sum()

# %%
df['Churn'].value_counts()

# %%
df.describe()

# %%
# tenure vs churn maybe
import matplotlib.pyplot as plt
df.groupby('Churn')['tenure'].hist(alpha=0.6)
plt.show()

# %%
# monthly charges looks important
df.groupby('Churn')['MonthlyCharges'].mean()
